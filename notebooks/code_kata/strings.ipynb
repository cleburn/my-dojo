# %% [markdown]
# # **Strings**
#
# - Take a sentence and count how many words it has
# - Convert it to all uppercase
# - Replace one word with another

# %%
string = "Henry wants nuggies and Boerne Taco House."

string_count = len(string.split())
print(string_count)
# Out:
# 7

# %%
print(string.upper())
# Out:
# HENRY WANTS NUGGIES AND BOERNE TACO HOUSE.

# %%
new_string = string.replace('wants','needs')
print(new_string)
# Out:
# Henry needs nuggies and Boerne Taco House.

# %%
import pandas as pd

df = pd.read_csv('../../data/raw/listings.csv')
df.shape
# Out:
# (15187, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15187 entries, 0 to 15186
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            15187 non-null  int64
#  1   listing_url                                   15187 non-null  object
#  2   scrape_id                                     15187 non-null  int64
#  3   last_scraped                                  15187 non-null  object
#  4   source                                        15187 non-null  object
#  5   name                                          15187 non-null  object
#  6   description                                   14840 non-null  object
#  7   neighborhood_overview                         7914 non-null   object
#  8   picture_url                                   15186 non-null  object
# ...

# %%
pd.set_option('display.max_rows',None)
df.head(1).T
# Out:
#                                                                                               0
# id                                                                                         5456
# listing_url                                                   https://www.airbnb.com/rooms/5456
# scrape_id                                                                        20250613040113
# last_scraped                                                                         2025-06-13
# source                                                                              city scrape
# name                                                  Walk to 6th, Rainey St and Convention Ctr
# description                                   Great central  location for walking to Convent...
# neighborhood_overview                         My neighborhood is ideally located if you want...
# picture_url                                   https://a0.muscache.com/pictures/14084884/b5a3...
# ...

# %%
df['price'] = df['price'].str.replace('[^\d.]','',regex=True).astype(float)
df.head(3)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  5456  https://www.airbnb.com/rooms/5456  20250613040113   2025-06-13
# 1  5769  https://www.airbnb.com/rooms/5769  20250613040113   2025-06-13
# 2  6413  https://www.airbnb.com/rooms/6413  20250613040113   2025-06-14
#
#             source                                       name  \
# 0      city scrape  Walk to 6th, Rainey St and Convention Ctr
# 1      city scrape                             NW Austin Room
# 2  previous scrape              Gem of a Studio near Downtown
#
#                                          description  \
# 0  Great central  location for walking to Convent...
# 1                                                NaN
# 2  Great studio apartment, perfect a single perso...
#
#                                neighborhood_overview  \
# 0  My neighborhood is ideally located if you want...
# 1  Quiet neighborhood with lots of trees and good...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15187 entries, 0 to 15186
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            15187 non-null  int64
#  1   listing_url                                   15187 non-null  object
#  2   scrape_id                                     15187 non-null  int64
#  3   last_scraped                                  15187 non-null  object
#  4   source                                        15187 non-null  object
#  5   name                                          15187 non-null  object
#  6   description                                   14840 non-null  object
#  7   neighborhood_overview                         7914 non-null   object
#  8   picture_url                                   15186 non-null  object
# ...

# %%
narrowed_df = df.groupby('listing_url')[['estimated_occupancy_l365d','estimated_revenue_l365d']].max().head(20)
narrowed_df.sort_values('estimated_revenue_l365d',ascending=False).head(20)
# Out:
#                                                   estimated_occupancy_l365d  \
# listing_url
# https://www.airbnb.com/rooms/1000016109686428185                        186
# https://www.airbnb.com/rooms/1002881780954180678                        255
# https://www.airbnb.com/rooms/1001539944471972916                        255
# https://www.airbnb.com/rooms/1000949971433207571                        174
# https://www.airbnb.com/rooms/1001685419002718517                        132
# https://www.airbnb.com/rooms/1002845018120279086                        252
# https://www.airbnb.com/rooms/1001303                                     60
# https://www.airbnb.com/rooms/10015237                                   112
# https://www.airbnb.com/rooms/1002280080104423709                        255
# https://www.airbnb.com/rooms/1002323696641538827                        224
# https://www.airbnb.com/rooms/1000214231632561366                         42
# ...

# %%
narrowed_df.loc[['https://www.airbnb.com/rooms/1000016109686428185','https://www.airbnb.com/rooms/1002881780954180678']]
# Out:
#                                                   estimated_occupancy_l365d  \
# listing_url
# https://www.airbnb.com/rooms/1000016109686428185                        186
# https://www.airbnb.com/rooms/1002881780954180678                        255
#
#                                                   estimated_revenue_l365d
# listing_url
# https://www.airbnb.com/rooms/1000016109686428185                 181908.0
# https://www.airbnb.com/rooms/1002881780954180678                  72930.0

# %%
top_2 = narrowed_df.sort_values('estimated_revenue_l365d', ascending=False).head(2)
top_2_urls = top_2.index

full_data = df[df['listing_url'].isin(top_2_urls)]
pd.set_option('display.max_columns',None)
full_data
# Out:
#                         id                                       listing_url  \
# 10343  1000016109686428185  https://www.airbnb.com/rooms/1000016109686428185
# 10360  1002881780954180678  https://www.airbnb.com/rooms/1002881780954180678
#
#             scrape_id last_scraped       source  \
# 10343  20250613040113   2025-06-13  city scrape
# 10360  20250613040113   2025-06-14  city scrape
#
#                                                     name  \
# 10343   Cozy Lakeway Paradise: Hot Tub, Fire Pit & Games
# 10360  WOW | Chill + Chic Austin Hub | 12BR Modern Ma...
#
#                                              description  \
# 10343  Whether a peaceful and relaxing vacation or a ...
# 10360  Experience Austin in Style! Discover our uniqu...
#
#       neighborhood_overview  \
# 10343                   NaN
# 10360                   NaN
#
#                                              picture_url    host_id  \
# 10343  https://a0.muscache.com/pictures/prohost-api/H...  301565646
# ...

# %%
#import matplotlib.pyplot as plt

#print

#plt.scatter(data=df,x='neighbourhood_cleansed',y='estimated_revenue_l365d', alpha=0.4)

#plt.xlabel('ZIP Codes')
#plt.ylabel('Estimated Revenue ($)')
#plt.title('Is it the area, or an Outlier?')
#plt.show()
