# %%
import pandas as pd
import numpy as np

print("All imports successful")
# Out:
# All imports successful

# %%
print(sum(num for num in range(7)))
# Out:
# 21

# %%
num = 21
total = 0

for val in range(num):
    total += val
print(total)
# Out:
# 210

# %%
def is_palindrome(s):
    cleaned = ''.join(char.lower() for char in s if char.isalnum())
    return cleaned == cleaned[::-1]

user_input = input("Enter a sentence to check for palindrome: ")

if is_palindrome(user_input):
    print("✅ It's a palindrome!")
else:
    print("❌ Not a palindrome.")
# Out:
# Enter a sentence to check for palindrome:  racecar
# ✅ It's a palindrome!

# %%
def tip_calculator(bill, tip):
    bill = float(bill)
    tip = float(tip/100)
    total_due = bill + (bill * tip)
    return print(f"Total: ${total_due:.2f}")

tip_calculator(120, 15)
# Out:
# Total: $138.00
