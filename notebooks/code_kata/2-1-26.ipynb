# %%
nums = [1,2,3,4,5]

squares = [num**2 for num in nums]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
import pandas as pd

data = {
    'model': ['Llama 3', 'GPT-4', 'Claude 3.5'],
    'params_b': [8, 1700, None]
}

df = pd.DataFrame(data)
print(df)
# Out:
#         model  params_b
# 0     Llama 3       8.0
# 1       GPT-4    1700.0
# 2  Claude 3.5       NaN

# %%
small_models = df[df['params_b'] < 100]
print(small_models)
# Out:
#      model  params_b
# 0  Llama 3       8.0

# %%
df = df.fillna(0)
print(df)
# Out:
#         model  params_b
# 0     Llama 3       8.0
# 1       GPT-4    1700.0
# 2  Claude 3.5       0.0

# %%
filename = "training_data.csv"
print(filename[-4:])
# Out:
# .csv

# %%
def calculate_accuracy(correct, total):
    return float(correct/total)

print(calculate_accuracy(80, 100))
# Out:
# 0.8

# %%
for num in range(1,6):
    if num == 3:
        print("Found it!")
    else:
        print(num)
# Out:
# 1
# 2
# Found it!
# 4
# 5

# %%
metrics = {'accuracy': 0.95, 'latency': 0.02}

for key,val in metrics.items():
    print(f"Key: {key}, Value: {val}")
# Out:
# Key: accuracy, Value: 0.95
# Key: latency, Value: 0.02

# %%
scores = [80,85,90]

avg_score = sum(scores)/len(scores)
print(avg_score)
# Out:
# 85.0

# %%
df['is_huge'] = df['params_b'] > 1000
print(df)
# Out:
#         model  params_b  is_huge
# 0     Llama 3       8.0    False
# 1       GPT-4    1700.0     True
# 2  Claude 3.5       0.0    False

# %%
units_sold = 8472
avg_price = 34.7
conversion_rate = 0.1825

print(f"Units: {units_sold:,}")
print(f"Avg Price: ${avg_price:.2f}")
print(f"Conversion: {conversion_rate*100:.1f}%")
# Out:
# Units: 8,472
# Avg Price: $34.70
# Conversion: 18.2%

# %%
names = ["alice", "bob", "carol", "dan"]
proper_names = [name.title() for name in names]
print(proper_names)
# Out:
# ['Alice', 'Bob', 'Carol', 'Dan']

# %%
inventory = {"apples": 50, "bananas": 32, "oranges": 41}
for key,val in inventory.items():
    print(f"{key}: {val} units")
# Out:
# apples: 50 units
# bananas: 32 units
# oranges: 41 units

# %%
df = pd.DataFrame({
    "rep": ["Amy", "Amy", "Ben", "Ben", "Amy", "Ben"],
    "deal_size": [1200, 800, 1500, 2200, 950, 1800],
    "closed": [True, True, False, True, True, True]
})

total_closed_size = df[df['closed'] == True]['deal_size'].sum()
print(total_closed_size)
# Out:
# 6950

# %%
tasks = ["Review PR", "Write tests", "Deploy", "Update docs"]
for i,task in enumerate(tasks, start=1):
    print(f"{i}. {task}")
# Out:
# 1. Review PR
# 2. Write tests
# 3. Deploy
# 4. Update docs

# %%
values = [15, 42, 8, 91, 33, 67]

high_low_values = ["high" if value >= 50 else "low" for value in values]

print(high_low_values)
# Out:
# ['low', 'low', 'low', 'high', 'low', 'high']

# %%
df2 = pd.DataFrame({
    "category": ["A", "B", "A", "B", "A"],
    "sales": [100, 150, 200, 175, 125]
})

df2.groupby('category')['sales'].mean()
# Out:
# category
# A    141.666667
# B    162.500000
# Name: sales, dtype: float64

# %%
month = ["Jan", "Feb", "Mar"]
revenue = [12000, 15000, 11000]

combined = list(zip(month,revenue))
print(combined)
# Out:
# [('Jan', 12000), ('Feb', 15000), ('Mar', 11000)]

# %%
df3 = pd.DataFrame({
    "product": ["Widget", "Gadget", "Gizmo", "Thingamajig"],
    "units": [340, 275, 410, 195],
    "price": [25, 40, 15, 60]
})

df3.sort_values('units', ascending=False).head(2)[['product','units']]
# Out:
#   product  units
# 2   Gizmo    410
# 0  Widget    340

# %%
config = {"host": "localhost", "port": 5432}

config.get("timeout", 30)
# Out:
# 30
