# %%
prices = [12.99, 45.00, 8.50, 23.75, 99.99]

prices_plus_tax = [(num + num*0.15) for num in prices]

print(prices_plus_tax)
# Out:
# [14.9385, 51.75, 9.775, 27.3125, 114.98849999999999]

# %%
groceries = ["eggs", "milk", "bread", "cheese", "apples"]
for i, food in enumerate(groceries, start=1):
    print(f"{i}. {food}")
# Out:
# 1. eggs
# 2. milk
# 3. bread
# 4. cheese
# 5. apples
