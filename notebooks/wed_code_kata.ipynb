# %%
practice_sentence = "There will be a day and it will be filled with coffay"
print(len(practice_sentence.split()))
# Out:
# 12

# %%
sentence = "I'm ready for my morning coffee!"
words = sentence.split()
print(words)
print(len(words))
# Out:
# ["I'm", 'ready', 'for', 'my', 'morning', 'coffee!']
# 6

# %%
print(practice_sentence.lower())
print(practice_sentence.title())
print(sentence.upper())
# Out:
# there will be a day and it will be filled with coffay
# There Will Be A Day And It Will Be Filled With Coffay
# I'M READY FOR MY MORNING COFFEE!

# %%
print(practice_sentence.replace('coffay','coffee'))
# Out:
# There will be a day and it will be filled with coffee

# %%
import pandas as pd
df = pd.read_csv('../data/processed/processed_data.csv')

# %%
df.head()
# Out:
#    RegionID  SizeRank       RegionName    RegionType StateName State    City  \
# 0    416968       768    West Oak Hill  neighborhood        TX    TX  Austin
# 1    271652       992     Windsor Park  neighborhood        TX    TX  Austin
# 2    275057      1156  Pleasant Valley  neighborhood        TX    TX  Austin
# 3    271391      1205    Franklin Park  neighborhood        TX    TX  Austin
# 4    271353      1435         Downtown  neighborhood        TX    TX  Austin
#
#                               Metro     CountyName     2000-01-31  ...  \
# 0  Austin-Round Rock-Georgetown, TX  Travis County  225656.567739  ...
# 1  Austin-Round Rock-Georgetown, TX  Travis County  225656.567739  ...
# 2  Austin-Round Rock-Georgetown, TX  Travis County  116702.212787  ...
# 3  Austin-Round Rock-Georgetown, TX  Travis County   76944.526694  ...
# 4  Austin-Round Rock-Georgetown, TX  Travis County   76944.526694  ...
#
# ...

# %%
df.shape
# Out:
# (56, 338)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Columns: 338 entries, RegionID to str_vs_ltr_cashflow_delta
# dtypes: float64(326), int64(3), object(9)
# memory usage: 148.0+ KB

# %%
df.describe()
# Out:
#             RegionID      SizeRank     2000-01-31     2000-02-29  \
# count      56.000000     56.000000      56.000000      56.000000
# mean   318920.267857   5799.910714  188817.190071  183391.318940
# std    149710.848685   5297.880016  139932.125271  134001.894368
# min    231200.000000    768.000000   76944.526694   77264.519555
# 25%    271392.500000   2380.250000  108313.916668  110378.695330
# 50%    271587.500000   4295.000000  136996.284701  145483.680403
# 75%    274152.250000   6702.250000  243078.809700  195212.214901
# max    814367.000000  23737.000000  754635.808599  750023.940970
#
#           2000-03-31     2000-04-30     2000-05-31     2000-06-30  \
# count      56.000000      56.000000      56.000000      56.000000
# mean   184575.096956  185548.304819  186368.489118  187237.393796
# std    134920.631728  135472.889298  136821.108092  138726.738921
# min     77610.130469   78173.337594   78628.474093   78703.478709
# ...

# %%
df.columns.tolist()
# Out:
# ['RegionID',
#  'SizeRank',
#  'RegionName',
#  'RegionType',
#  'StateName',
#  'State',
#  'City',
#  'Metro',
#  'CountyName',
#  '2000-01-31',
#  '2000-02-29',
#  '2000-03-31',
#  '2000-04-30',
#  '2000-05-31',
#  '2000-06-30',
#  '2000-07-31',
#  '2000-08-31',
#  '2000-09-30',
#  '2000-10-31',
#  '2000-11-30',
#  '2000-12-31',
#  '2001-01-31',
#  '2001-02-28',
#  '2001-03-31',
#  '2001-04-30',
#  '2001-05-31',
#  '2001-06-30',
#  '2001-07-31',
#  '2001-08-31',
#  '2001-09-30',
#  '2001-10-31',
#  '2001-11-30',
#  '2001-12-31',
#  '2002-01-31',
#  '2002-02-28',
#  '2002-03-31',
#  '2002-04-30',
#  '2002-05-31',
#  '2002-06-30',
#  '2002-07-31',
#  '2002-08-31',
#  '2002-09-30',
#  '2002-10-31',
#  '2002-11-30',
#  '2002-12-31',
#  '2003-01-31',
#  '2003-02-28',
#  '2003-03-31',
#  '2003-04-30',
#  '2003-05-31',
#  '2003-06-30',
#  '2003-07-31',
#  '2003-08-31',
#  '2003-09-30',
#  '2003-10-31',
#  '2003-11-30',
#  '2003-12-31',
#  '2004-01-31',
#  '2004-02-29',
#  '2004-03-31',
# ...

# %%
df['income_potential'] = df['median_nightly_rate'] * df['occupancy_rate']
df.sort_values('income_potential',ascending=False).head(10)
# Out:
#     RegionID  SizeRank           RegionName    RegionType StateName  ...  \
# 23    271325      3696  Central East Austin  neighborhood        TX  ...
# 44    273354      7263       Coronado Hills  neighborhood        TX  ...
# 32    271474      4456                  MLK  neighborhood        TX  ...
# 24    271437      3949            Hyde Park  neighborhood        TX  ...
# 45    273440      7465               Dawson  neighborhood        TX  ...
# 17    271497      3054          North Lamar  neighborhood        TX  ...
# 41    271360      6663    East Cesar Chavez  neighborhood        TX  ...
# 16    271665      3001               Wooten  neighborhood        TX  ...
# 54    814367     21685     Kensington Place  neighborhood        TX  ...
# 37    271501      5182     North University  neighborhood        TX  ...
#
#    monthly_costs str_monthly_cash_flow ltr_monthly_cash_flow  \
# 23   4105.399564           -253.399564          -2564.599564
# ...

# %%
pd.set_option('display.max_rows',None)
df[['neighborhood','occupancy_rate','median_nightly_rate','income_potential']]
# Out:
#            neighborhood  occupancy_rate  median_nightly_rate  income_potential
# 0         West Oak Hill            42.0                131.0            5502.0
# 1          Windsor Park            36.0                117.0            4212.0
# 2       Pleasant Valley             0.0                136.0               0.0
# 3         Franklin Park            36.0                128.5            4626.0
# 4              Downtown             0.0                172.5               0.0
# 5             Allandale            36.0                179.0            6444.0
# 6            Montopolis            18.0                122.0            2196.0
# 7          North Burnet            36.0                120.0            4320.0
# 8             Brentwood            18.0                100.5            1809.0
# 9             St. Johns            12.0                 77.0             924.0
# 10               Zilker            40.0                138.0            5520.0
# ...
